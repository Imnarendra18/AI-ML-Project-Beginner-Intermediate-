# %%
import pandas as pd
import numpy as np

# %%
# Core libraries
import pandas as pd
import numpy as np

# Optional imports for specific tasks
from pandas import DataFrame, Series        # Direct access to DataFrame and Series
from pandas import read_csv, read_excel     # Read CSV/Excel files
from pandas import concat, merge, pivot_table  # Common pandas functions

# NumPy specific functions (optional, if you want shortcuts)
from numpy import array, arange, linspace, zeros, ones, eye, reshape
from numpy import mean, median, std, sum, min, max
from numpy import random                     # Random number generation

# %%
student=pd.read_csv('data/student_info.csv')

# %%
student

# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
adult = fetch_ucirepo(id=2) 
  
# data (as pandas dataframes) 
X = adult.data.features 
y = adult.data.targets 
  
# metadata 
print(adult.metadata) 
  
# variable information 
print(adult.variables)
