# %% [markdown]
# Tutorial 4: Implement Simple Linear Regression

# %%
import pandas as pd
import numpy as np

# %%
computer=pd.read_csv('data/computers.csv')

# %%
computer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Units    14 non-null     int64
#  1   Minutes  14 non-null     int64
# dtypes: int64(2)
# memory usage: 356.0 bytes

# %%
computer.head()
# Out:
#    Units  Minutes
# 0      1       23
# 1      2       29
# 2      3       49
# 3      4       64
# 4      4       74

# %%
computer.tail()
# Out:
#     Units  Minutes
# 9       8      119
# 10      9      149
# 11      9      145
# 12     10      154
# 13     10      166

# %%
computer.isna().sum()
# Out:
# Units      0
# Minutes    0
# dtype: int64

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk

import numpy as np
import sklearn

# %%
computer =pd.read_csv('data/computers.csv')

# %%
plt.scatter(data/computers['Units'], computers['Minutes'])
plt.xlabel("Units")
plt.ylabel("Minutes")
plt.title("Units vs Minutes")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 plt.scatter(data/computers['Units'], computers['Minutes'])
#       2 plt.xlabel("Units")
#       3 plt.ylabel("Minutes")
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

computers = pd.read_csv("data/computers.csv")

# %%
computers.head()
# Out:
#    Units  Minutes
# 0      1       23
# 1      2       29
# 2      3       49
# 3      4       64
# 4      4       74

# %%
plt.scatter(computers['Units'], computers['Minutes'])
plt.xlabel("Units")
plt.ylabel("Minutes")
plt.title("Units vs Minutes")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

X = computers[['Units']]
Y = computers['Minutes']

model = LinearRegression()
model.fit(X, Y)

print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_[0])
# Out:
# Intercept: 4.161654135338296
# Coefficient: 15.508771929824569

# %%
computers['Predicted_Minutes'] = model.predict(X)

# %%
plt.scatter(computers['Units'], computers['Minutes'], label="Actual")
plt.plot(computers['Units'], computers['Predicted_Minutes'], label="Regression Line")

plt.xlabel("Units")
plt.ylabel("Minutes")
plt.legend()
plt.show()

# %%
model0 = computer['Minutes'].mean()
model0
# Out:
# np.float64(97.21428571428571)

# %%
model1 = 10 + 12 * computer['Units']
model1
# Out:
# 0      22
# 1      34
# 2      46
# 3      58
# 4      58
# 5      70
# 6      82
# 7      82
# 8      94
# 9     106
# 10    118
# 11    118
# 12    130
# 13    130
# Name: Units, dtype: int64

# %%
model2 = 6 + 18 * computer['Units']
model2
# Out:
# 0      24
# 1      42
# 2      60
# 3      78
# 4      78
# 5      96
# 6     114
# 7     114
# 8     132
# 9     150
# 10    168
# 11    168
# 12    186
# 13    186
# Name: Units, dtype: int64

# %%
computer['model_0'] = model0
computer['model_1'] = model1
computer['model_2'] = model2

# %%
computer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Units    14 non-null     int64
#  1   Minutes  14 non-null     int64
#  2   model_0  14 non-null     float64
#  3   model_1  14 non-null     int64
#  4   model_2  14 non-null     int64
# dtypes: float64(1), int64(4)
# memory usage: 692.0 bytes

# %%
computer
# Out:
#     Units  Minutes    model_0  model_1  model_2
# 0       1       23  97.214286       22       24
# 1       2       29  97.214286       34       42
# 2       3       49  97.214286       46       60
# 3       4       64  97.214286       58       78
# 4       4       74  97.214286       58       78
# 5       5       87  97.214286       70       96
# 6       6       96  97.214286       82      114
# 7       6       97  97.214286       82      114
# 8       7      109  97.214286       94      132
# 9       8      119  97.214286      106      150
# 10      9      149  97.214286      118      168
# 11      9      145  97.214286      118      168
# 12     10      154  97.214286      130      186
# 13     10      166  97.214286      130      186

# %%
fig,ax=plt.subplots()

# %%
fig,ax=plt.subplots()
ax.scatter(x='Units', y='Minutes', data=computer, label='Actual repair time')
ax.plot(computer['Units'], computer['model_0'], color='red', label='Model 0')
ax.plot(computer['Units'], computer['model_1'], color='green', label='Model 1')
ax.plot(computer['Units'], computer['model_2'], color='orange', label='Model 2')
ax.set_xlabel('Units')
# Out:
# Text(0.5, 0, 'Units')

# %%
ax.plot(computer['Units'], computer['model_0'], color='red', label='Model 0')
ax.set_xlabel('Units')
# Out:
# Text(0.5, 24.0, 'Units')

# %% [markdown]
# Building a regression model using the scikit-learn library

# %%
x=computer[['Units']]
y=computer['Minutes']
from sklearn.metrics import mean_squared_error
model3=LinearRegression()
model3.fit(x,y)
print("Intercept:", model3.intercept_)
print("Coefficient:", model3.coef_)
# Out:
# Intercept: 4.161654135338296
# Coefficient: [15.50877193]

# %%
# Creating Linear Regression model with calculated coefficient and intercept.
model_3 = 4.16 + 15.50 * computer['Units']
computer['model_3'] = model_3
computer
# Out:
#     Units  Minutes    model_0  model_1  model_2  model_3
# 0       1       23  97.214286       22       24    19.66
# 1       2       29  97.214286       34       42    35.16
# 2       3       49  97.214286       46       60    50.66
# 3       4       64  97.214286       58       78    66.16
# 4       4       74  97.214286       58       78    66.16
# 5       5       87  97.214286       70       96    81.66
# 6       6       96  97.214286       82      114    97.16
# 7       6       97  97.214286       82      114    97.16
# 8       7      109  97.214286       94      132   112.66
# 9       8      119  97.214286      106      150   128.16
# 10      9      149  97.214286      118      168   143.66
# 11      9      145  97.214286      118      168   143.66
# 12     10      154  97.214286      130      186   159.16
# 13     10      166  97.214286      130      186   159.16

# %%
fig,ax=plt.subplots()
ax.scatter(x='Units', y='Minutes', data=computer, label='Actual repair time')
ax.plot(computer['Units'], computer['model_0'], color='red', label='Model 0')
ax.plot(computer['Units'], computer['model_1'], color='green', label='Model 1')
ax.plot(computer['Units'], computer['model_2'], color='orange', label='Model 2')
ax.plot(computer['Units'], computer['model_3'], color='blue', label='Model 3')
ax.set_xlabel('Units')
# Out:
# Text(0.5, 0, 'Units')

# %%
rsq=model3.score(computer[['Units']],y)*100

# %%
rsq
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 rsq
#
# NameError: name 'rsq' is not defined

# %% [markdown]
# Tutorial 5:Multiple Linear Regression Model

# %%
std=pd.read_csv('data/std_marks_data.csv')

# %%
std
# Out:
#      hours  age  internet  marks
# 0     6.84   15         0  78.64
# 1     6.56   20         1  88.80
# 2      NaN   21         1  88.90
# 3     8.67   22         1  98.99
# 4     7.55   17         1  92.34
# ..     ...  ...       ...    ...
# 295   2.99   25         0  43.45
# 296   6.55   15         1  77.74
# 297   0.00   20         1  75.76
# 298   9.90   22         0  99.99
# 299   3.40   21         0  99.99
#
# [300 rows x 4 columns]

# %%
std.head()
# Out:
#    hours  age  internet  marks
# 0   6.84   15         0  78.64
# 1   6.56   20         1  88.80
# 2    NaN   21         1  88.90
# 3   8.67   22         1  98.99
# 4   7.55   17         1  92.34

# %%
std.tail()
# Out:
#      hours  age  internet  marks
# 295   2.99   25         0  43.45
# 296   6.55   15         1  77.74
# 297   0.00   20         1  75.76
# 298   9.90   22         0  99.99
# 299   3.40   21         0  99.99

# %%
std.isna().sum()
# Out:
# hours       12
# age          0
# internet     0
# marks        0
# dtype: int64

# %%
std.hours=std.hours.fillna(std.hours.mean())

# %%
x=std.iloc[:, :-1]

# %%
x
# Out:
#         hours  age  internet
# 0    6.840000   15         0
# 1    6.560000   20         1
# 2    5.494514   21         1
# 3    8.670000   22         1
# 4    7.550000   17         1
# ..        ...  ...       ...
# 295  2.990000   25         0
# 296  6.550000   15         1
# 297  0.000000   20         1
# 298  9.900000   22         0
# 299  3.400000   21         0
#
# [300 rows x 3 columns]

# %%
y=std.iloc[:, -1]

# %%
y
# Out:
# 0      78.64
# 1      88.80
# 2      88.90
# 3      98.99
# 4      92.34
#        ...
# 295    43.45
# 296    77.74
# 297    75.76
# 298    99.99
# 299    99.99
# Name: marks, Length: 300, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x.train, x.test, y.train, y.test = train_test_split(x, y, test_size=0.2)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
x.train.shape
# Out:
# (240, 3)

# %%
y.train.shape
# Out:
# (240,)

# %%
y.test.shape
# Out:
# (60,)

# %%
x.test.shape
# Out:
# (60, 3)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
# Out:
# Intercept: 62.403770383977836
# Coefficients: [1.12562108 0.17885318 2.86204273]

# %%
hours=int(input("Enter number of hours studied: "))
age=int(input("Enter age of the student: "))
internet=int(input("Enter internet access (1 for Yes, 0 for No): "))
data=[[hours, age, internet]]
print("Predicted Marks:", model.predict(data))
# Out:
# Predicted Marks: [225.48738662]
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
hours = int(input("Enter number of hours studied: "))
age = int(input("Enter age of the student: "))
internet = int(input("Enter internet access (1 for Yes, 0 for No): "))

data = [[hours, age, internet]]   # 2D input

prediction = model.predict(data)
print("Predicted Marks:", prediction[0])

# %%
data=pd.read_csv('data/chd_data.csv')

# %%
data.head()
# Out:
#    age  chd
# 0   20    0
# 1   23    0
# 2   24    0
# 3   25    1
# 4   25    0

# %%
data.tail()
# Out:
#     age  chd
# 95   63    1
# 96   64    1
# 97   64    0
# 98   65    1
# 99   69    1

# %%
plt.scatter("age", "chd", data=data)
plt.xlabel("Age")
plt.ylabel("CHD")
plt.title("Age vs CHD")
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     100 non-null    int64
#  1   chd     100 non-null    int64
# dtypes: int64(2)
# memory usage: 1.7 KB

# %%
from sklearn.model_selection import train_test_split
prediction=["age"]
target=["chd"]
x=data[prediction]
y=data[target]
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3 )
print("shapes of x_train:", X_train.shape)
print("shapes of x_test:", X_test.shape)
print("shapes of y_train:", y_train.shape)
print("shapes of y_test:", y_test.shape)
# Out:
# shapes of x_train: (70, 1)
# shapes of x_test: (30, 1)
# shapes of y_train: (70, 1)
# shapes of y_test: (30, 1)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_)
# Out:
# Intercept: [-0.45405066]
# Coefficient: [[0.0206778]]

# %%
test=int(input("Enter age to predict CHD: "))
data=[[test]]
prediction=model.predict(data)
print("Predicted CHD:", prediction[0])
# Out:
# Predicted CHD: [0.43509472]
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
if prediction[0] == 1:
    print("CHD Risk: YES")
else:
    print("CHD Risk: NO")
# Out:
# CHD Risk: NO

# %%
from sklearn.metrics import accuracy_score, f1_score

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7666666666666667

# %%
f1 = f1_score(y_test, y_pred)
print("F1 Score:", f1)
# Out:
# F1 Score: 0.6956521739130435

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.7666666666666667
# Recall: 0.8
# F1 Score: 0.6956521739130435
